# %% [markdown]
# # Data
#
# ## Download MOOC Data
# - download data from server: http://moocdata.cn/data/user-activity
# - Note: This may take a while!!
# - Bash script can be found here [data_download.sh](data_download.sh)

# %%
# %%bash
#
# echo "Downloading data from server"
# file="data/prediction_data.tar.gz"
# if [[ -f "$file" ]]; then
#     echo "$file exists."
# else
#     curl -s -o $file http://lfs.aminer.cn/misc/moocdata/data/prediction_data.tar.gz
#     echo "Extracting files from $file..."
#     tar -C data -xzvf data/prediction_data.tar.gz
#     echo "Done extracting files."
# fi
#
# file="data/user_info.csv"
# if [[ -f "$file" ]]; then
#     echo "$file exists."
# else
#     echo "Downloading $file..."
#     curl -s -o $file http://lfs.aminer.cn/misc/moocdata/data/user_info.csv
# fi
#
# file="data/course_info.csv"
# if [[ -f "$file" ]]; then
#     echo "$file exists"
# else
#     echo "Downloading $file..."
#     curl -s -o $file http://lfs.aminer.cn/misc/moocdata/data/course_info.csv
# fi
#
# echo "All done..."
# Out:
# Downloading data from server
# data/prediction_data.tar.gz exists.
# data/user_info.csv exists.
# data/course_info.csv exists
# All done...

# %% [markdown]
# ## Feature Extraction
# - preprocessing step: https://github.com/wzfhaha/dropout_prediction/blob/master/feat_extract.py

# %%
import os
import pandas as pd

# %%
pd.__version__
# Out:
# '1.1.1'

# %%
data_path = 'data'

# load training log
train = pd.read_csv(os.path.join(data_path, 'prediction_log/train_log.csv'))

# %%
# let's look at the first 5 records
train.head()
# description of feature can be found here: http://moocdata.cn/data/user-activity
# Out:
#    enroll_id  username                              course_id  \
# 0        772      5981  course-v1:TsinghuaX+70800232X+2015_T2
# 1        772      5981  course-v1:TsinghuaX+70800232X+2015_T2
# 2        773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# 3        773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# 4        773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
#
#                          session_id       action  \
# 0  d8a9b787fa69063c34c73b9c29190b1c  click_about
# 1  d8a9b787fa69063c34c73b9c29190b1c   click_info
# 2  2f02b86eb3ea2cbf0be11385a8dc62e5  pause_video
# 3  2f02b86eb3ea2cbf0be11385a8dc62e5   load_video
# 4  2f02b86eb3ea2cbf0be11385a8dc62e5   play_video
#
#                              object                 time
# 0                               NaN  2015-09-27T15:42:59
# 1                               NaN  2015-09-27T15:43:12
# 2  3dac5590435e43b3a65a9ae7426c16db  2015-10-19T19:37:42
# 3  3dac5590435e43b3a65a9ae7426c16db  2015-10-19T19:33:27
# 4  3dac5590435e43b3a65a9ae7426c16db  2015-10-19T19:33:30

# %%
# let's look at the last 5 records
train.tail()
# Out:
#           enroll_id  username                              course_id  \
# 29165535     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165536     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165537     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165538     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
# 29165539     466786   2659552  course-v1:TsinghuaX+AP000001X+2016_T1
#
#                                 session_id            action  \
# 29165535  dff9476c7f05f26a69a06506fe471668  click_courseware
# 29165536  dff9476c7f05f26a69a06506fe471668       problem_get
# 29165537  dff9476c7f05f26a69a06506fe471668       problem_get
# 29165538  dff9476c7f05f26a69a06506fe471668       problem_get
# 29165539  d94bf93252b8936bef09f6e46c24d50d       click_about
#
#                                     object                 time
# 29165535                               NaN  2016-04-01T21:04:38
# 29165536  556186425e7448e189918bafcb2ff30b  2016-04-01T21:04:38
# 29165537  1757e4fd85994ba9a2350780f96da89e  2016-04-01T21:04:38
# 29165538  686d5efcd27845379b4b90e41ece181d  2016-04-01T21:04:38
# 29165539                               NaN  2016-03-02T20:21:55

# %%
# read the ground truch for training data
train_truth = pd.read_csv(os.path.join(data_path, 'prediction_log/train_truth.csv'), index_col='enroll_id')

# %%
# 1 -> drop-out; and 0 -> not-drop-out
train_truth.head()
# Out:
#            truth
# enroll_id
# 772            1
# 773            1
# 774            1
# 776            0
# 777            1

# %%
train_truth.tail()
# Out:
#            truth
# enroll_id
# 466774         1
# 466776         1
# 466781         1
# 466782         1
# 466786         0

# %%
# user action categories
video_actions = ['seek_video','play_video','pause_video','stop_video','load_video']
problem_actions = ['problem_get','problem_check','problem_save','reset_problem','problem_check_correct', 'problem_check_incorrect']
forum_actions = ['create_thread','create_comment','delete_thread','delete_comment']
click_actions = ['click_info','click_courseware','click_about','click_forum','click_progress']
close_actions = ['close_courseware']

# %%
# load test logs
test = pd.read_csv(os.path.join(data_path, 'prediction_log/test_log.csv'))
test_truth = pd.read_csv(os.path.join(data_path, 'prediction_log/test_truth.csv'), index_col='enroll_id')

# cobmine train and test truth
all_truth = pd.concat([train_truth, test_truth])

# combine train and test logs
all_log = pd.concat([train, test])

# %%
all_log.head()
# Out:
#    enroll_id  username                              course_id  \
# 0        772      5981  course-v1:TsinghuaX+70800232X+2015_T2
# 1        772      5981  course-v1:TsinghuaX+70800232X+2015_T2
# 2        773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# 3        773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
# 4        773   1544995  course-v1:TsinghuaX+70800232X+2015_T2
#
#                          session_id       action  \
# 0  d8a9b787fa69063c34c73b9c29190b1c  click_about
# 1  d8a9b787fa69063c34c73b9c29190b1c   click_info
# 2  2f02b86eb3ea2cbf0be11385a8dc62e5  pause_video
# 3  2f02b86eb3ea2cbf0be11385a8dc62e5   load_video
# 4  2f02b86eb3ea2cbf0be11385a8dc62e5   play_video
#
#                              object                 time
# 0                               NaN  2015-09-27T15:42:59
# 1                               NaN  2015-09-27T15:43:12
# 2  3dac5590435e43b3a65a9ae7426c16db  2015-10-19T19:37:42
# 3  3dac5590435e43b3a65a9ae7426c16db  2015-10-19T19:33:27
# 4  3dac5590435e43b3a65a9ae7426c16db  2015-10-19T19:33:30

# %%
all_log.tail()
# Out:
#           enroll_id  username                              course_id  \
# 12944857     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944858     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944859     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944860     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
# 12944861     466785   2513464  course-v1:TsinghuaX+AP000001X+2016_T1
#
#                                 session_id                   action  \
# 12944857  b12bc83e13cd943cf61bf78f09c72158  problem_check_incorrect
# 12944858  b12bc83e13cd943cf61bf78f09c72158  problem_check_incorrect
# 12944859  b12bc83e13cd943cf61bf78f09c72158    problem_check_correct
# 12944860  7eca0904ae14dc8af809c0362632dd8e         click_courseware
# 12944861  b12bc83e13cd943cf61bf78f09c72158              problem_get
#
#                                     object                 time
# 12944857  31aa97345c46473badab334379f995d8  2016-03-19T21:37:15
# 12944858  31aa97345c46473badab334379f995d8  2016-03-19T21:37:22
# 12944859  31aa97345c46473badab334379f995d8  2016-03-19T21:37:37
# 12944860                               NaN  2016-03-19T19:24:44
# 12944861  a028651adbdc4bc0b53191117f874fbc  2016-03-19T21:38:34

# %%
train_enroll = list(set(list(train['enroll_id'])))
test_enroll = list(set(list(test['enroll_id'])))

# %%
# let's check train and test list
print(len(train_enroll))
print(len(test_enroll))
# Out:
# 157943
# 67699

# %%
# count all the actions for each user
user_action_count = all_log.groupby('enroll_id').count()[['action']]

# %%
user_action_count
# Out:
#            action
# enroll_id
# 772             2
# 773            21
# 774            74
# 775            39
# 776            19
# ...           ...
# 466781         29
# 466782         24
# 466783          2
# 466785         50
# 466786         93
#
# [225642 rows x 1 columns]

# %%
# give columns names
user_action_count.columns = ['action_count']

# %%
user_action_count
# Out:
#            action_count
# enroll_id
# 772                   2
# 773                  21
# 774                  74
# 775                  39
# 776                  19
# ...                 ...
# 466781               29
# 466782               24
# 466783                2
# 466785               50
# 466786               93
#
# [225642 rows x 1 columns]

# %%
# create online session_enroll df dropping all duplicate session_ids
session_enroll = all_log[['session_id']].drop_duplicates()

# %%
session_enroll.head()
# Out:
#                           session_id
# 0   d8a9b787fa69063c34c73b9c29190b1c
# 2   2f02b86eb3ea2cbf0be11385a8dc62e5
# 23  26449d5b9c0dfd76bdf981410ef33d94
# 24  fd2ad174b4aa8f6dd3e8900e1ba62735
# 56  138155092c1a9ce258b0da27a169b14d

# %%
session_count = all_log.groupby('enroll_id').count()

# %%
session_count.head()
# Out:
#            username  course_id  session_id  action  object  time
# enroll_id
# 772               2          2           2       2       0     2
# 773              21         21          21      21      14    21
# 774              74         74          74      74      42    74
# 775              39         39          39      39      30    39
# 776              19         19          19      19       9    19

# %%
user_action_count['session_count'] = session_count['session_id']

# %%
user_action_count.head()
# Out:
#            action_count  session_count
# enroll_id
# 772                   2              2
# 773                  21             21
# 774                  74             74
# 775                  39             39
# 776                  19             19

# %%
user_action_count.tail()
# Out:
#            action_count  session_count
# enroll_id
# 466781               29             29
# 466782               24             24
# 466783                2              2
# 466785               50             50
# 466786               93             93

# %%
for action in video_actions + problem_actions + forum_actions + click_actions + close_actions:
    action_label = action+'_count'
    action_ = (all_log['action'] == action).astype(int)
    all_log[action_label] = action_
    action_num = all_log.groupby('enroll_id').sum()[[action_label]]
    user_action_count = pd.merge(user_action_count, action_num, left_index=True, right_index=True)

# %%
user_action_count.head()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 772                   2              2                 0                 0
# 773                  21             21                 6                 4
# 774                  74             74                 9                14
# 775                  39             39                 0                12
# 776                  19             19                 0                 3
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 772                        0                 0                 0
# 773                        3                 0                 1
# 774                       10                 1                 8
# 775                        6                 2                10
# 776                        3                 1                 2
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 772                        0                    0                   0  ...
# 773                        0                    0                   0  ...
# 774                        0                    0                   0  ...
# 775                        0                    0                   0  ...
# 776                        0                    0                   0  ...
#
#            create_thread_count  create_comment_count  delete_thread_count  \
# enroll_id
# 772                          0                     0                    0
# 773                          0                     0                    0
# 774                          0                     0                    0
# 775                          0                     0                    0
# 776                          0                     0                    0
#
#            delete_comment_count  click_info_count  click_courseware_count  \
# enroll_id
# 772                           0                 1                       0
# 773                           0                 2                       2
# 774                           0                 6                      17
# 775                           0                 0                       0
# 776                           0                 2                       4
#
#            click_about_count  click_forum_count  click_progress_count  \
# enroll_id
# 772                        1                  0                     0
# 773                        2                  0                     0
# 774                        0                  0                     0
# 775                        0                  0                     0
# 776                        2                  0                     0
#
#            close_courseware_count
# enroll_id
# 772                             0
# 773                             1
# 774                             9
# 775                             9
# 776                             2
#
# [5 rows x 23 columns]

# %%
user_action_count.tail()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 466781               29             29                 0                 0
# 466782               24             24                 0                 1
# 466783                2              2                 0                 0
# 466785               50             50                 1                 2
# 466786               93             93                 0                 0
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 466781                     0                 0                 0
# 466782                     1                 0                 1
# 466783                     0                 0                 0
# 466785                     4                 0                 2
# 466786                     2                 0                 2
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 466781                    22                    0                   0  ...
# 466782                     3                    0                   0  ...
# 466783                     0                    0                   0  ...
# 466785                    14                    0                   0  ...
# 466786                    25                    0                   0  ...
#
#            create_thread_count  create_comment_count  delete_thread_count  \
# enroll_id
# 466781                       0                     0                    0
# 466782                       0                     0                    0
# 466783                       0                     0                    0
# 466785                       0                     0                    0
# 466786                       0                     0                    0
#
#            delete_comment_count  click_info_count  click_courseware_count  \
# enroll_id
# 466781                        0                 0                       0
# 466782                        0                 4                       5
# 466783                        0                 0                       0
# 466785                        0                 2                       4
# 466786                        0                16                      16
#
#            click_about_count  click_forum_count  click_progress_count  \
# enroll_id
# 466781                     0                  0                     0
# 466782                     4                  2                     0
# 466783                     2                  0                     0
# 466785                     4                  0                     0
# 466786                    12                  4                     8
#
#            close_courseware_count
# enroll_id
# 466781                          0
# 466782                          3
# 466783                          0
# 466785                          2
# 466786                          8
#
# [5 rows x 23 columns]

# %%
 user_action_count = pd.merge(user_action_count, all_truth, left_index=True, right_index=True)

# %%
user_action_count.head()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 772                   2              2                 0                 0
# 773                  21             21                 6                 4
# 774                  74             74                 9                14
# 775                  39             39                 0                12
# 776                  19             19                 0                 3
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 772                        0                 0                 0
# 773                        3                 0                 1
# 774                       10                 1                 8
# 775                        6                 2                10
# 776                        3                 1                 2
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 772                        0                    0                   0  ...
# 773                        0                    0                   0  ...
# 774                        0                    0                   0  ...
# 775                        0                    0                   0  ...
# 776                        0                    0                   0  ...
#
#            create_comment_count  delete_thread_count  delete_comment_count  \
# enroll_id
# 772                           0                    0                     0
# 773                           0                    0                     0
# 774                           0                    0                     0
# 775                           0                    0                     0
# 776                           0                    0                     0
#
#            click_info_count  click_courseware_count  click_about_count  \
# enroll_id
# 772                       1                       0                  1
# 773                       2                       2                  2
# 774                       6                      17                  0
# 775                       0                       0                  0
# 776                       2                       4                  2
#
#            click_forum_count  click_progress_count  close_courseware_count  \
# enroll_id
# 772                        0                     0                       0
# 773                        0                     0                       1
# 774                        0                     0                       9
# 775                        0                     0                       9
# 776                        0                     0                       2
#
#            truth
# enroll_id
# 772            1
# 773            1
# 774            1
# 775            1
# 776            0
#
# [5 rows x 24 columns]

# %%
user_action_count.tail()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 466781               29             29                 0                 0
# 466782               24             24                 0                 1
# 466783                2              2                 0                 0
# 466785               50             50                 1                 2
# 466786               93             93                 0                 0
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 466781                     0                 0                 0
# 466782                     1                 0                 1
# 466783                     0                 0                 0
# 466785                     4                 0                 2
# 466786                     2                 0                 2
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 466781                    22                    0                   0  ...
# 466782                     3                    0                   0  ...
# 466783                     0                    0                   0  ...
# 466785                    14                    0                   0  ...
# 466786                    25                    0                   0  ...
#
#            create_comment_count  delete_thread_count  delete_comment_count  \
# enroll_id
# 466781                        0                    0                     0
# 466782                        0                    0                     0
# 466783                        0                    0                     0
# 466785                        0                    0                     0
# 466786                        0                    0                     0
#
#            click_info_count  click_courseware_count  click_about_count  \
# enroll_id
# 466781                    0                       0                  0
# 466782                    4                       5                  4
# 466783                    0                       0                  2
# 466785                    2                       4                  4
# 466786                   16                      16                 12
#
#            click_forum_count  click_progress_count  close_courseware_count  \
# enroll_id
# 466781                     0                     0                       0
# 466782                     2                     0                       3
# 466783                     0                     0                       0
# 466785                     0                     0                       2
# 466786                     4                     8                       8
#
#            truth
# enroll_id
# 466781         1
# 466782         1
# 466783         1
# 466785         1
# 466786         0
#
# [5 rows x 24 columns]

# %%
# remove duplicates based on username, course_id and enroll_id
enroll_info = all_log[['username','course_id','enroll_id']].drop_duplicates()

# %%
enroll_info.head()
# Out:
#      username                              course_id  enroll_id
# 0        5981  course-v1:TsinghuaX+70800232X+2015_T2        772
# 2     1544995  course-v1:TsinghuaX+70800232X+2015_T2        773
# 23    1072798  course-v1:TsinghuaX+70800232X+2015_T2        774
# 97     561867  course-v1:TsinghuaX+70800232X+2015_T2        776
# 116   1368125  course-v1:TsinghuaX+70800232X+2015_T2        777

# %%
enroll_info.tail()
# Out:
#           username                              course_id  enroll_id
# 12944714   2670958  course-v1:TsinghuaX+AP000001X+2016_T1     466770
# 12944762   2582621  course-v1:TsinghuaX+AP000001X+2016_T1     466775
# 12944781    133215  course-v1:TsinghuaX+AP000001X+2016_T1     466777
# 12944810   2665176  course-v1:TsinghuaX+AP000001X+2016_T1     466783
# 12944812   2513464  course-v1:TsinghuaX+AP000001X+2016_T1     466785

# %%
enroll_info.index = enroll_info['enroll_id']
del enroll_info['enroll_id']

# %%
user_action_count = pd.merge(user_action_count, enroll_info, left_index=True, right_index=True)

# %%
user_action_count.head()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 772                   2              2                 0                 0
# 773                  21             21                 6                 4
# 774                  74             74                 9                14
# 775                  39             39                 0                12
# 776                  19             19                 0                 3
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 772                        0                 0                 0
# 773                        3                 0                 1
# 774                       10                 1                 8
# 775                        6                 2                10
# 776                        3                 1                 2
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 772                        0                    0                   0  ...
# 773                        0                    0                   0  ...
# 774                        0                    0                   0  ...
# 775                        0                    0                   0  ...
# 776                        0                    0                   0  ...
#
#            delete_comment_count  click_info_count  click_courseware_count  \
# enroll_id
# 772                           0                 1                       0
# 773                           0                 2                       2
# 774                           0                 6                      17
# 775                           0                 0                       0
# 776                           0                 2                       4
#
#            click_about_count  click_forum_count  click_progress_count  \
# enroll_id
# 772                        1                  0                     0
# 773                        2                  0                     0
# 774                        0                  0                     0
# 775                        0                  0                     0
# 776                        2                  0                     0
#
#            close_courseware_count  truth  username  \
# enroll_id
# 772                             0      1      5981
# 773                             1      1   1544995
# 774                             9      1   1072798
# 775                             9      1   1520977
# 776                             2      0    561867
#
#                                        course_id
# enroll_id
# 772        course-v1:TsinghuaX+70800232X+2015_T2
# 773        course-v1:TsinghuaX+70800232X+2015_T2
# 774        course-v1:TsinghuaX+70800232X+2015_T2
# 775        course-v1:TsinghuaX+70800232X+2015_T2
# 776        course-v1:TsinghuaX+70800232X+2015_T2
#
# [5 rows x 26 columns]

# %%
# save into corresponding train and test data set
user_action_count.loc[test_enroll].to_csv(os.path.join(data_path, 'test_features.csv'))
user_action_count.loc[train_enroll].to_csv(os.path.join(data_path, 'train_features.csv'))

# %% [markdown]
# ## Feature Preprocessing

# %%
import os
import pandas as pd
import numpy as np
import pickle as pkl
import math
from sklearn.preprocessing import StandardScaler

# %%
def age_convert(year):
    if year == None or math.isnan(year):
        return 0
    age = 2018 - int(year)
    if age > 70 or age < 10:
        age = 0
    return age

# %%
def gender_convert(gender):
    if gender == 'm':
        return 1
    elif gender == 'f':
        return 2
    else:
        return 0

# %%
def edu_convert(edu):
    edus = ["Bachelor's","High", "Master's", "Primary", "Middle","Associate","Doctorate"]
    #if x == None or or math.isnan(x):
    #    return 0
    if not isinstance(edu, str):
        return 0
    eduIndex = edus.index(edu)
    return eduIndex+1

# %%
def category_convert(category):
    if not isinstance(category, str):
        return 0
    categories = ['math','physics','electrical', 'computer','foreign language', 
                'business', 'economics','biology','medicine','literature','philosophy',
                'history','social science', 'art','engineering','education','environment','chemistry']
                
    catIndex = categories.index(category)
    return catIndex+1

# %%
data_path = 'data'

train_features = pd.read_csv(os.path.join(data_path, 'train_features.csv'), index_col=0)
test_features = pd.read_csv(os.path.join(data_path, 'test_features.csv'), index_col=0)

# %%
train_features.head()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 772                   2              2                 0                 0
# 773                  21             21                 6                 4
# 774                  74             74                 9                14
# 776                  19             19                 0                 3
# 777                   4              4                 0                 0
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 772                        0                 0                 0
# 773                        3                 0                 1
# 774                       10                 1                 8
# 776                        3                 1                 2
# 777                        0                 0                 0
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 772                        0                    0                   0  ...
# 773                        0                    0                   0  ...
# 774                        0                    0                   0  ...
# 776                        0                    0                   0  ...
# 777                        0                    0                   0  ...
#
#            delete_comment_count  click_info_count  click_courseware_count  \
# enroll_id
# 772                           0                 1                       0
# 773                           0                 2                       2
# 774                           0                 6                      17
# 776                           0                 2                       4
# 777                           0                 1                       1
#
#            click_about_count  click_forum_count  click_progress_count  \
# enroll_id
# 772                        1                  0                     0
# 773                        2                  0                     0
# 774                        0                  0                     0
# 776                        2                  0                     0
# 777                        1                  0                     0
#
#            close_courseware_count  truth  username  \
# enroll_id
# 772                             0      1      5981
# 773                             1      1   1544995
# 774                             9      1   1072798
# 776                             2      0    561867
# 777                             1      1   1368125
#
#                                        course_id
# enroll_id
# 772        course-v1:TsinghuaX+70800232X+2015_T2
# 773        course-v1:TsinghuaX+70800232X+2015_T2
# 774        course-v1:TsinghuaX+70800232X+2015_T2
# 776        course-v1:TsinghuaX+70800232X+2015_T2
# 777        course-v1:TsinghuaX+70800232X+2015_T2
#
# [5 rows x 26 columns]

# %%
train_features.tail()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 466774               42             42                 0                 0
# 466776               19             19                 3                 2
# 466781               29             29                 0                 0
# 466782               24             24                 0                 1
# 466786               93             93                 0                 0
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 466774                     2                 0                 2
# 466776                     2                 1                 2
# 466781                     0                 0                 0
# 466782                     1                 0                 1
# 466786                     2                 0                 2
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 466774                     6                    4                   0  ...
# 466776                     0                    0                   0  ...
# 466781                    22                    0                   0  ...
# 466782                     3                    0                   0  ...
# 466786                    25                    0                   0  ...
#
#            delete_comment_count  click_info_count  click_courseware_count  \
# enroll_id
# 466774                        0                 3                       4
# 466776                        0                 2                       3
# 466781                        0                 0                       0
# 466782                        0                 4                       5
# 466786                        0                16                      16
#
#            click_about_count  click_forum_count  click_progress_count  \
# enroll_id
# 466774                    11                  0                     4
# 466776                     2                  0                     0
# 466781                     0                  0                     0
# 466782                     4                  2                     0
# 466786                    12                  4                     8
#
#            close_courseware_count  truth  username  \
# enroll_id
# 466774                          2      1   2588048
# 466776                          2      1   2736225
# 466781                          0      1   2830711
# 466782                          3      1   2680742
# 466786                          8      0   2659552
#
#                                        course_id
# enroll_id
# 466774     course-v1:TsinghuaX+AP000001X+2016_T1
# 466776     course-v1:TsinghuaX+AP000001X+2016_T1
# 466781     course-v1:TsinghuaX+AP000001X+2016_T1
# 466782     course-v1:TsinghuaX+AP000001X+2016_T1
# 466786     course-v1:TsinghuaX+AP000001X+2016_T1
#
# [5 rows x 26 columns]

# %%
all_features = pd.concat([train_features, test_features])

# %%
all_features.shape
# Out:
# (225642, 26)

# %%
user_profile_df = pd.read_csv(os.path.join(data_path, 'user_info.csv'), index_col='user_id')
# Out:
# /Users/rbasnet/miniconda3/envs/ml/lib/python3.7/site-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
user_profile_df.head()
# Out:
#         gender   education   birth
# user_id
# 631       male        High  1997.0
# 2631      male  Bachelor's  1990.0
# 4231      male   Associate  1991.0
# 6031      male  Bachelor's  1988.0
# 7831       NaN         NaN     NaN

# %%
user_profile_df.tail()
# Out:
#          gender education  birth
# user_id
# 10435606    NaN       NaN    NaN
# 10437206    NaN       NaN    NaN
# 10438806    NaN       NaN    NaN
# 10440406    NaN       NaN    NaN
# 10442006    NaN       NaN    NaN

# %%
# extract user age
birth_year = user_profile_df['birth'].to_dict()

# %%
birth_year
# Out:
# {631: 1997.0,
#  2631: 1990.0,
#  4231: 1991.0,
#  6031: 1988.0,
#  7831: nan,
#  9631: 1992.0,
#  11231: 1985.0,
#  13631: nan,
#  16031: 1986.0,
#  18231: 1987.0,
#  22431: 1995.0,
#  26231: 1968.0,
#  28431: 1991.0,
#  31231: 1987.0,
#  33231: 1981.0,
#  35631: 1990.0,
#  37831: 1987.0,
#  40031: 1990.0,
#  42031: 1995.0,
#  44031: 1990.0,
#  46431: nan,
#  48231: nan,
#  50631: 1983.0,
#  52431: 1963.0,
#  55631: 1998.0,
#  59231: 1989.0,
#  61431: 1989.0,
#  64031: nan,
#  66231: nan,
#  68431: 1986.0,
#  70231: 1983.0,
#  71831: 1990.0,
#  74031: 1995.0,
#  75631: 1993.0,
#  77631: 1975.0,
#  79431: 1993.0,
#  81031: 1982.0,
#  83031: nan,
#  84831: 1989.0,
#  86631: 1978.0,
#  88631: 1975.0,
#  90231: 1981.0,
#  92431: 1984.0,
#  94031: nan,
#  95631: nan,
#  97631: nan,
#  100831: 1992.0,
#  102631: 1986.0,
#  104831: 1987.0,
#  107031: nan,
#  109231: 1995.0,
#  111431: 1989.0,
#  113031: 1996.0,
#  115231: 1994.0,
#  116831: 1988.0,
#  118431: 1990.0,
#  1014231: nan,
#  1015831: nan,
#  1017431: nan,
#  1019231: nan,
#  1021031: 1997.0,
#  1022631: 1997.0,
#  1024231: 1996.0,
#  1025831: 1996.0,
#  1027431: 1996.0,
#  1029031: 1996.0,
#  1030631: 1995.0,
#  1032231: 1996.0,
#  1033831: 1996.0,
#  1035431: 1994.0,
#  1037031: nan,
#  1038631: nan,
#  1040231: nan,
#  1041831: nan,
#  1043431: nan,
#  1045031: nan,
#  1046631: nan,
#  1048231: nan,
#  1049831: nan,
#  1051431: nan,
#  1053031: nan,
#  1055031: nan,
#  1056631: nan,
#  1058631: 1994.0,
#  1060231: 1992.0,
#  1061831: 1994.0,
#  1063431: nan,
#  1065031: nan,
#  1066831: nan,
#  1068431: nan,
#  1070031: nan,
#  1071631: nan,
#  1073231: nan,
#  1074831: nan,
#  1076431: nan,
#  1078031: nan,
#  1079631: nan,
#  1081431: nan,
#  1083031: nan,
#  1084631: nan,
#  1086231: nan,
#  1087831: nan,
#  1089631: nan,
#  1091231: nan,
#  1092831: nan,
#  1094631: nan,
#  1096231: nan,
#  1097831: nan,
#  1099431: nan,
#  1101031: nan,
#  1102631: nan,
#  1104431: nan,
#  1106231: nan,
#  1108031: nan,
#  1109631: nan,
#  1111231: nan,
#  1112831: nan,
#  1114431: nan,
#  1117431: 1996.0,
#  1119431: 1997.0,
#  1121031: 1995.0,
#  1122631: 1995.0,
#  1125031: 1993.0,
#  1127431: 1995.0,
#  1129031: 1993.0,
#  1131431: 1994.0,
#  1133631: nan,
#  1135231: nan,
#  1136831: 1992.0,
#  1138631: 1994.0,
#  1140631: 1994.0,
#  1142231: 1995.0,
#  1143831: 1993.0,
#  1145831: 1999.0,
#  1147431: 1996.0,
#  1149031: 1994.0,
#  1150631: 1994.0,
#  1152231: 1996.0,
#  1153831: 1995.0,
#  1155431: nan,
#  1157231: nan,
#  1158831: nan,
#  1160431: nan,
#  1162631: nan,
#  1164631: nan,
#  1166231: nan,
#  1168631: nan,
#  1170231: nan,
#  1172631: nan,
#  1175631: nan,
#  1178431: nan,
#  1181231: nan,
#  1182831: nan,
#  1184631: nan,
#  1186431: nan,
#  1188031: nan,
#  1189631: nan,
#  1191231: nan,
#  1192831: nan,
#  1194431: nan,
#  1196031: nan,
#  1197631: nan,
#  1199231: nan,
#  1200831: nan,
#  1202431: nan,
#  1204831: nan,
#  1206431: nan,
#  1208031: nan,
#  1209631: nan,
#  1211231: nan,
#  1212831: nan,
#  1214431: nan,
#  1216031: nan,
#  1217631: nan,
#  1219231: nan,
#  1220831: nan,
#  1222431: nan,
#  1224031: nan,
#  1225631: nan,
#  1227231: nan,
#  1228831: nan,
#  1230431: nan,
#  1232031: nan,
#  1241831: nan,
#  1243431: nan,
#  1245031: nan,
#  1246631: nan,
#  1248231: nan,
#  1249831: nan,
#  1251431: nan,
#  1253031: nan,
#  1254631: nan,
#  1256231: nan,
#  1257831: nan,
#  1259431: nan,
#  1261031: nan,
#  1262631: nan,
#  1264231: nan,
#  1746031: 1995.0,
#  1747631: 1996.0,
#  1749231: 1993.0,
#  1750831: 1995.0,
#  1752431: 1996.0,
#  1754031: 1995.0,
#  1755631: 1996.0,
#  1757231: 1996.0,
#  1758831: 1996.0,
#  1760431: 1995.0,
#  1762031: 1996.0,
#  1763631: nan,
#  1765231: nan,
#  1766831: nan,
#  1768431: nan,
#  1770031: nan,
#  1771631: nan,
#  1773231: nan,
#  1774831: nan,
#  1776631: nan,
#  1778231: nan,
#  1779831: nan,
#  1781431: nan,
#  1783031: nan,
#  1784631: nan,
#  1786231: nan,
#  1787831: nan,
#  1789631: nan,
#  1791231: nan,
#  1792831: nan,
#  1794431: nan,
#  1796031: nan,
#  1797631: nan,
#  1799231: nan,
#  1800831: nan,
#  1802431: nan,
#  1804031: nan,
#  1805631: nan,
#  1807231: nan,
#  1808831: nan,
#  1810431: nan,
#  1812031: nan,
#  ...}

# %%
# add user's age as feature
all_features['age'] = [age_convert(birth_year.get(int(u), None)) for u in all_features['username']]

# %%
all_features.head()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 772                   2              2                 0                 0
# 773                  21             21                 6                 4
# 774                  74             74                 9                14
# 776                  19             19                 0                 3
# 777                   4              4                 0                 0
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 772                        0                 0                 0
# 773                        3                 0                 1
# 774                       10                 1                 8
# 776                        3                 1                 2
# 777                        0                 0                 0
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 772                        0                    0                   0  ...
# 773                        0                    0                   0  ...
# 774                        0                    0                   0  ...
# 776                        0                    0                   0  ...
# 777                        0                    0                   0  ...
#
#            click_info_count  click_courseware_count  click_about_count  \
# enroll_id
# 772                       1                       0                  1
# 773                       2                       2                  2
# 774                       6                      17                  0
# 776                       2                       4                  2
# 777                       1                       1                  1
#
#            click_forum_count  click_progress_count  close_courseware_count  \
# enroll_id
# 772                        0                     0                       0
# 773                        0                     0                       1
# 774                        0                     0                       9
# 776                        0                     0                       2
# 777                        0                     0                       1
#
#            truth  username                              course_id  age
# enroll_id
# 772            1      5981  course-v1:TsinghuaX+70800232X+2015_T2   29
# 773            1   1544995  course-v1:TsinghuaX+70800232X+2015_T2    0
# 774            1   1072798  course-v1:TsinghuaX+70800232X+2015_T2    0
# 776            0    561867  course-v1:TsinghuaX+70800232X+2015_T2   37
# 777            1   1368125  course-v1:TsinghuaX+70800232X+2015_T2    0
#
# [5 rows x 27 columns]

# %%
# extract user gender
user_gender = user_profile_df['gender'].to_dict()
# add gender feature to all_features
all_features['gender'] = [gender_convert(user_gender.get(int(u), None)) for u in all_features['username']]

# %%
all_features.head()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 772                   2              2                 0                 0
# 773                  21             21                 6                 4
# 774                  74             74                 9                14
# 776                  19             19                 0                 3
# 777                   4              4                 0                 0
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 772                        0                 0                 0
# 773                        3                 0                 1
# 774                       10                 1                 8
# 776                        3                 1                 2
# 777                        0                 0                 0
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 772                        0                    0                   0  ...
# 773                        0                    0                   0  ...
# 774                        0                    0                   0  ...
# 776                        0                    0                   0  ...
# 777                        0                    0                   0  ...
#
#            click_courseware_count  click_about_count  click_forum_count  \
# enroll_id
# 772                             0                  1                  0
# 773                             2                  2                  0
# 774                            17                  0                  0
# 776                             4                  2                  0
# 777                             1                  1                  0
#
#            click_progress_count  close_courseware_count  truth  username  \
# enroll_id
# 772                           0                       0      1      5981
# 773                           0                       1      1   1544995
# 774                           0                       9      1   1072798
# 776                           0                       2      0    561867
# 777                           0                       1      1   1368125
#
#                                        course_id  age  gender
# enroll_id
# 772        course-v1:TsinghuaX+70800232X+2015_T2   29       0
# 773        course-v1:TsinghuaX+70800232X+2015_T2    0       0
# 774        course-v1:TsinghuaX+70800232X+2015_T2    0       0
# 776        course-v1:TsinghuaX+70800232X+2015_T2   37       0
# 777        course-v1:TsinghuaX+70800232X+2015_T2    0       0
#
# [5 rows x 28 columns]

# %%
# extract education and add it as a feature
user_edu = user_profile_df['education'].to_dict()
all_features['education'] = [edu_convert(user_edu.get(int(u), None)) for u in all_features['username']]

# %%
user_enroll_count = all_features.groupby('username').count()[['course_id']]

# %%
user_enroll_count
# Out:
#           course_id
# username
# 5                12
# 7                 2
# 26                7
# 32                3
# 35                3
# ...             ...
# 7011178           1
# 7019483           1
# 7023562           1
# 7036067           1
# 7059814           1
#
# [77083 rows x 1 columns]

# %%
course_enroll_count = all_features.groupby('course_id').count()[['username']]

# %%
course_enroll_count.head()
# Out:
#                               username
# course_id
# CAU/08112500x/2015_T2              394
# MITx/15_390x_2015_T1/2015_T1       742
# MITx/6_041x/2014_T2                582
# NCTU/nctucmpsd/2015_T2             510
# TsinghuaX/00680082X/2016_T1        621

# %%
user_enroll_count.columns = ['user_enroll_count']
course_enroll_count.columns = ['course_enroll_count']

# %%
all_features = pd.merge(all_features, user_enroll_count, left_on='username', right_index=True)

# %%
all_features.head()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 772                   2              2                 0                 0
# 73833                 3              3                 0                 0
# 198737                4              4                 0                 0
# 209393                2              2                 0                 0
# 418643               12             12                 0                 1
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 772                        0                 0                 0
# 73833                      0                 0                 0
# 198737                     0                 0                 0
# 209393                     0                 0                 0
# 418643                     2                 1                 1
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 772                        0                    0                   0  ...
# 73833                      0                    0                   0  ...
# 198737                     0                    0                   0  ...
# 209393                     0                    0                   0  ...
# 418643                     0                    0                   0  ...
#
#            click_forum_count  click_progress_count  close_courseware_count  \
# enroll_id
# 772                        0                     0                       0
# 73833                      0                     1                       0
# 198737                     0                     2                       0
# 209393                     0                     0                       0
# 418643                     0                     2                       1
#
#            truth  username                                course_id  age  \
# enroll_id
# 772            1      5981    course-v1:TsinghuaX+70800232X+2015_T2   29
# 73833          1      5981       course-v1:HIT+13SC20301820+2015_T2   29
# 198737         1      5981  course-v1:TsinghuaX+30240184_1X+2016_T1   29
# 209393         1      5981       course-v1:NTHU+MOOC_00_005+2015_T2   29
# 418643         1      5981    course-v1:TsinghuaX+80511503X+2016_T1   29
#
#            gender  education  user_enroll_count
# enroll_id
# 772             0          3                  6
# 73833           0          3                  6
# 198737          0          3                  6
# 209393          0          3                  6
# 418643          0          3                  6
#
# [5 rows x 30 columns]

# %%
all_features = pd.merge(all_features, course_enroll_count, left_on='course_id', right_index=True)

# %%
all_features.head()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 772                   2              2                 0                 0
# 773                  21             21                 6                 4
# 774                  74             74                 9                14
# 776                  19             19                 0                 3
# 777                   4              4                 0                 0
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 772                        0                 0                 0
# 773                        3                 0                 1
# 774                       10                 1                 8
# 776                        3                 1                 2
# 777                        0                 0                 0
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 772                        0                    0                   0  ...
# 773                        0                    0                   0  ...
# 774                        0                    0                   0  ...
# 776                        0                    0                   0  ...
# 777                        0                    0                   0  ...
#
#            click_progress_count  close_courseware_count  truth  username  \
# enroll_id
# 772                           0                       0      1      5981
# 773                           0                       1      1   1544995
# 774                           0                       9      1   1072798
# 776                           0                       2      0    561867
# 777                           0                       1      1   1368125
#
#                                        course_id  age  gender  education  \
# enroll_id
# 772        course-v1:TsinghuaX+70800232X+2015_T2   29       0          3
# 773        course-v1:TsinghuaX+70800232X+2015_T2    0       0          0
# 774        course-v1:TsinghuaX+70800232X+2015_T2    0       0          0
# 776        course-v1:TsinghuaX+70800232X+2015_T2   37       0          6
# 777        course-v1:TsinghuaX+70800232X+2015_T2    0       0          0
#
#            user_enroll_count  course_enroll_count
# enroll_id
# 772                        6                 1333
# 773                        2                 1333
# 774                        5                 1333
# 776                        6                 1333
# 777                       11                 1333
#
# [5 rows x 31 columns]

# %%
all_features.tail()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 424714              274            274                65                56
# 424720               10             10                 2                 1
# 424243              371            371                 4                71
# 424555              636            636               190                64
# 424585              151            151                15                24
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 424714                    62                 5                14
# 424720                     2                 0                 0
# 424243                    89                15                29
# 424555                    97                21                44
# 424585                    38                 7                14
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 424714                     0                    0                   0  ...
# 424720                     0                    0                   0  ...
# 424243                     3                    6                   0  ...
# 424555                    10                   13                   4  ...
# 424585                     1                    2                   1  ...
#
#            click_progress_count  close_courseware_count  truth  username  \
# enroll_id
# 424714                        0                      17      1   6776637
# 424720                        0                       0      1   6776128
# 424243                        0                      36      1   6776321
# 424555                        4                      52      1   6775492
# 424585                        0                       2      0   6776600
#
#                                        course_id  age  gender  education  \
# enroll_id
# 424714     course-v1:TsinghuaX+00670122X+2017_T1    0       0          0
# 424720     course-v1:TsinghuaX+00670122X+2017_T1    0       0          0
# 424243     course-v1:TsinghuaX+00670122X+2017_T1    0       0          0
# 424555     course-v1:TsinghuaX+00670122X+2017_T1    0       0          0
# 424585     course-v1:TsinghuaX+00670122X+2017_T1    0       0          0
#
#            user_enroll_count  course_enroll_count
# enroll_id
# 424714                     2                  426
# 424720                     1                  426
# 424243                     1                  426
# 424555                     1                  426
# 424585                     1                  426
#
# [5 rows x 31 columns]

# %%
#extract course category
course_info_df = pd.read_csv(os.path.join(data_path, 'course_info.csv'), index_col='id')
category_dict = course_info_df['category'].to_dict()

# %%
category_dict
# Out:
# {'6561': nan,
#  '5557': nan,
#  '9433': nan,
#  '8320': nan,
#  '231': nan,
#  '7645': nan,
#  '9953': nan,
#  '7625': nan,
#  '8657': 'philosophy',
#  '8833': nan,
#  '3814': nan,
#  '9343': nan,
#  '8006': nan,
#  '2159': nan,
#  '10988': nan,
#  '9645': nan,
#  '11935': nan,
#  '577': 'engineering',
#  '11105': nan,
#  '9248': 'history',
#  '10488': nan,
#  '5745': nan,
#  '11899': nan,
#  '2296': nan,
#  '5873': nan,
#  '680': nan,
#  '10171': nan,
#  '1623': nan,
#  '8957': nan,
#  '5763': nan,
#  '1682': nan,
#  '10450': nan,
#  '7171': 'engineering',
#  '830s0': nan,
#  '10164': nan,
#  '8974': nan,
#  '9304': nan,
#  '10627': nan,
#  '5735': 'social science',
#  '8375': nan,
#  '10459': nan,
#  '11612': 'economics',
#  '8507': nan,
#  '8202': nan,
#  '7444': nan,
#  '9290': 'literature',
#  '9378': nan,
#  '8697': nan,
#  '11495': nan,
#  '7225': nan,
#  '7256': nan,
#  '9287': nan,
#  '3997': nan,
#  '5714': nan,
#  '614': nan,
#  '9083': 'history',
#  '7401': nan,
#  '10324': nan,
#  '1973': nan,
#  '2070': 'business',
#  '557': 'biology',
#  '12210': nan,
#  '7691': nan,
#  '1815': 'engineering',
#  '2139': nan,
#  '7829': nan,
#  '4728': nan,
#  '8367': nan,
#  '11384': nan,
#  '4270': 'physics',
#  '8245': nan,
#  '7978': nan,
#  '10107': nan,
#  '3554': nan,
#  '11428': nan,
#  '10975': nan,
#  '4542': 'computer',
#  '3408': nan,
#  '3797': nan,
#  '8637': 'foreign language',
#  '777': nan,
#  '8209': nan,
#  '8633': 'foreign language',
#  '7433': nan,
#  '12313': nan,
#  '10677': nan,
#  '7272': 'literature',
#  '11891': nan,
#  '11869': 'medicine',
#  '10184': nan,
#  '10358': nan,
#  '7974': nan,
#  '9510': nan,
#  '1384': nan,
#  '10298': nan,
#  '7186': nan,
#  '11740': nan,
#  '8531': nan,
#  '9411': nan,
#  '679': 'computer',
#  '11266': nan,
#  '2756': nan,
#  '10308': nan,
#  '6818': nan,
#  '227': 'foreign language',
#  '5642': nan,
#  '11213': 'math',
#  '10623': nan,
#  '4003': nan,
#  '7710': nan,
#  '2231': nan,
#  '8853': nan,
#  '6738': nan,
#  '11735': 'economics',
#  '3498': nan,
#  '8583': 'computer',
#  '9209': nan,
#  '8208': nan,
#  '3384': nan,
#  '6925': 'engineering',
#  '5021': 'literature',
#  '11139': nan,
#  '6520': nan,
#  '12223': nan,
#  '4220': nan,
#  '6019': nan,
#  '12321': nan,
#  '11214': nan,
#  '6347': nan,
#  '5489': 'engineering',
#  '10860': nan,
#  '184': 'history',
#  '7673': nan,
#  '10411': nan,
#  '1628': nan,
#  '5578': nan,
#  '8667': 'economics',
#  '2794': nan,
#  '8455': nan,
#  '9063': nan,
#  '11257': 'economics',
#  '6928': 'engineering',
#  '1638': nan,
#  '7197': 'foreign language',
#  '8702': nan,
#  '3481': nan,
#  '7101': nan,
#  '7486': nan,
#  '3994': nan,
#  '11875': nan,
#  '672': 'social science',
#  '11602': 'economics',
#  '6650': nan,
#  '10332': nan,
#  '754': nan,
#  '7706': nan,
#  '8898': nan,
#  '10480': nan,
#  '5880': 'computer',
#  '8650': 'history',
#  '3475': nan,
#  '9012': nan,
#  '6975': nan,
#  '2154': nan,
#  '8881': nan,
#  '7454': nan,
#  '6780': 'social science',
#  '512': 'social science',
#  '3412': nan,
#  '1502': nan,
#  '6579': nan,
#  '10514': nan,
#  '7623': nan,
#  '4478': 'engineering',
#  '6465': 'economics',
#  '7479': nan,
#  '9974': 'foreign language',
#  '9204': nan,
#  '12058': 'education',
#  '9022': nan,
#  '1754': nan,
#  '10151': 'foreign language',
#  '10284': nan,
#  '7998': nan,
#  '10259': 'computer',
#  '3448': nan,
#  '7773': nan,
#  '1996': nan,
#  '8506': nan,
#  '9005': nan,
#  '8256': nan,
#  '9260': 'education',
#  '3004': nan,
#  '8089': nan,
#  '9698': 'foreign language',
#  '10870': nan,
#  '7416': nan,
#  '1632': nan,
#  '9872': nan,
#  '11501': nan,
#  '11515': nan,
#  '4377': 'electrical',
#  '8040': nan,
#  '6521': nan,
#  '10629': nan,
#  '12086': nan,
#  '11236': 'art',
#  '9672': nan,
#  '3456': nan,
#  '1566': 'literature',
#  '10365': nan,
#  '611': 'math',
#  '12126': nan,
#  '1475': 'environment',
#  '4476': 'physics',
#  '5712': nan,
#  '8453': nan,
#  '8790': nan,
#  '6596': nan,
#  '11142': nan,
#  '9748': nan,
#  '7127': nan,
#  '7728': nan,
#  '10520': nan,
#  '5056': 'physics',
#  '11376': nan,
#  '7930': nan,
#  '6877': nan,
#  '10047': nan,
#  '7391': nan,
#  '3266': nan,
#  '11685': 'philosophy',
#  '8297': nan,
#  '11916': nan,
#  '5767': nan,
#  '11446': nan,
#  '9437': nan,
#  '482': nan,
#  '9543': nan,
#  '9471': nan,
#  '7151': 'computer',
#  '1691': nan,
#  '5220': nan,
#  '12315': nan,
#  '11846': nan,
#  '1809': nan,
#  '6761': nan,
#  '10998': nan,
#  '10246': nan,
#  '8210': nan,
#  '9242': nan,
#  '11675': 'social science',
#  '3912': nan,
#  '808': 'physics',
#  '11026': nan,
#  '7345': nan,
#  '1659': nan,
#  '11336': 'literature',
#  '7221': 'computer',
#  '9367': nan,
#  '11437': nan,
#  '2171': nan,
#  '5524': nan,
#  '1848': nan,
#  '6909': 'social science',
#  '11339': 'physics',
#  '6453': nan,
#  '8855': nan,
#  '688': 'business',
#  '4326': nan,
#  '2146': nan,
#  '8627': 'foreign language',
#  '11039': nan,
#  '5086': nan,
#  '3604': nan,
#  '6669': 'literature',
#  '5716': nan,
#  '5892': 'engineering',
#  '7184': nan,
#  '11100': nan,
#  '10757': nan,
#  '1789': nan,
#  '9785': nan,
#  '5284': nan,
#  '595': nan,
#  '11404': nan,
#  '3455': nan,
#  '11848': nan,
#  '10091': nan,
#  '7250': 'art',
#  '8444': nan,
#  '9532': nan,
#  '3954': nan,
#  '10754': nan,
#  '1694': nan,
#  '9257': 'education',
#  '692': 'environment',
#  '11436': nan,
#  '1989': nan,
#  '4564': 'social science',
#  '1779': nan,
#  '6870': nan,
#  '3924': nan,
#  '11010': 'chemistry',
#  '9512': nan,
#  '7863': 'social science',
#  '10131': nan,
#  '2790': nan,
#  '527': 'philosophy',
#  '3440': nan,
#  '12125': nan,
#  '7564': nan,
#  '8354': nan,
#  '6656': nan,
#  '8066': nan,
#  '12009': nan,
#  '8685': nan,
#  '2110': nan,
#  '9182': nan,
#  '11829': nan,
#  '548': 'engineering',
#  '2156': nan,
#  '11323': 'medicine',
#  '9520': 'physics',
#  '4375': 'foreign language',
#  '4147': nan,
#  '3510': 'social science',
#  '11719': 'philosophy',
#  '4900': nan,
#  '8699': nan,
#  '64': 'electrical',
#  '8193': nan,
#  '3101': nan,
#  '7705': nan,
#  '7775': nan,
#  '1852': nan,
#  '10122': nan,
#  '442': nan,
#  '9687': nan,
#  '7820': nan,
#  '4441': 'engineering',
#  '7640': nan,
#  '1557': 'physics',
#  '11137': 'business',
#  '10323': nan,
#  '8710': nan,
#  '10008': nan,
#  '1587': 'engineering',
#  '2698': 'social science',
#  '11175': nan,
#  '11355': nan,
#  '3371': nan,
#  '11623': 'education',
#  '1896': 'foreign language',
#  '6017': nan,
#  '11949': nan,
#  '9940': 'social science',
#  '5212': nan,
#  '7510': nan,
#  '1585': 'foreign language',
#  '3104': nan,
#  '11611': nan,
#  '5717': nan,
#  '2634': nan,
#  '1871': nan,
#  '1722': nan,
#  '7661': nan,
#  '2792': nan,
#  '3434': nan,
#  '10950': nan,
#  '1680': nan,
#  '10441': nan,
#  '8478': nan,
#  '6582': nan,
#  '77': nan,
#  '9728': 'business',
#  '7163': 'electrical',
#  '10397': nan,
#  '1837': nan,
#  '11743': nan,
#  '11695': nan,
#  '10938': nan,
#  '9816': nan,
#  '6926': nan,
#  '7240': 'art',
#  '11816': 'art',
#  '5013': nan,
#  '844': 'math',
#  '11826': nan,
#  '1442': 'computer',
#  '4345': 'electrical',
#  '10130': 'social science',
#  '5883': nan,
#  '8058': nan,
#  '269': nan,
#  '9958': nan,
#  '2905': 'computer',
#  '9150': 'literature',
#  '1417': nan,
#  '3093': nan,
#  '10854': nan,
#  '9589': nan,
#  '8164': nan,
#  '8079': nan,
#  '11487': nan,
#  '1593': nan,
#  '11749': 'foreign language',
#  '8732': nan,
#  '1755': nan,
#  '10800': nan,
#  '7993': nan,
#  '10782': nan,
#  '8586': 'art',
#  '10361': nan,
#  '11160': nan,
#  '1793': nan,
#  '7721': 'computer',
#  '9800': nan,
#  '2107': nan,
#  '8874': nan,
#  '8051': nan,
#  '10056': nan,
#  '2147': nan,
#  '7981': nan,
#  '10869': nan,
#  '10669': nan,
#  '7997': nan,
#  '1662': nan,
#  '9206': nan,
#  '8897': nan,
#  '7341': nan,
#  '10939': nan,
#  '7717': nan,
#  '9138': nan,
#  '8945': nan,
#  '167': 'physics',
#  '10734': nan,
#  '6871': nan,
#  '8872': nan,
#  '3926': nan,
#  '11332': 'business',
#  '7783': nan,
#  '6433': nan,
#  '598': 'biology',
#  '1903': nan,
#  '10430': nan,
#  '7229': nan,
#  '6848': nan,
#  '12261': nan,
#  '3189': nan,
#  '11958': nan,
#  '4371': 'physics',
#  '9235': nan,
#  '7417': nan,
#  '6556': nan,
#  '12050': nan,
#  '7727': nan,
#  '1734': nan,
#  '85': 'business',
#  '7697': nan,
#  '1516': 'biology',
#  '2632': nan,
#  '7192': 'math',
#  '11401': nan,
#  '11507': nan,
#  '11847': nan,
#  '2896': nan,
#  '3474': nan,
#  '10643': nan,
#  '1984': nan,
#  '7239': 'economics',
#  '8666': nan,
#  '8025': nan,
#  '8894': nan,
#  '689': nan,
#  '9335': 'education',
#  '6954': nan,
#  '11025': nan,
#  '8377': nan,
#  '7106': nan,
#  '9439': 'engineering',
#  '9561': 'education',
#  '9340': nan,
#  '6856': 'history',
#  '7193': nan,
#  '11432': nan,
#  '6778': 'philosophy',
#  '8706': nan,
#  '9028': nan,
#  '1782': 'computer',
#  '8952': nan,
#  '3964': nan,
#  '5064': nan,
#  '9559': 'medicine',
#  '7223': nan,
#  '3556': nan,
#  '5041': nan,
#  '11183': nan,
#  '8600': nan,
#  '10034': nan,
#  '3030': nan,
#  '9710': nan,
#  '1515': nan,
#  '542': 'engineering',
#  '3783': nan,
#  '8317': nan,
#  '7683': nan,
#  '11877': nan,
#  '7805': nan,
#  '2558': nan,
#  '8920': nan,
#  '9311': nan,
#  '11394': nan,
#  '5889': 'business',
#  '1851': nan,
#  '12280': nan,
#  '514': 'electrical',
#  '9926': nan,
#  '11031': nan,
#  '8906': nan,
#  '6574': nan,
#  '11330': 'economics',
#  '8705': nan,
#  '4199': nan,
#  '10485': nan,
#  '7643': nan,
#  '11389': nan,
#  '6723': nan,
#  '10678': nan,
#  '7481': nan,
#  '4512': 'philosophy',
#  '11666': 'social science',
#  '8518': nan,
#  '11102': nan,
#  '8395': nan,
#  '7199': 'economics',
#  '11489': nan,
#  '10776': nan,
#  '7090': nan,
#  '7473': nan,
#  '1817': nan,
#  '10451': nan,
#  '7642': nan,
#  '9869': 'philosophy',
#  '9344': nan,
#  '9115': nan,
#  '9883': nan,
#  '6686': nan,
#  '11109': 'electrical',
#  '8615': 'computer',
#  '11858': nan,
#  '8996': nan,
#  '12297': nan,
#  '8741': nan,
#  '7819': nan,
#  '5921': 'literature',
#  '9033': nan,
#  '9006': nan,
#  '10082': nan,
#  '615': nan,
#  '12141': nan,
#  '10904': nan,
#  '11559': nan,
#  '6602': nan,
#  '11957': nan,
#  '9963': nan,
#  '9416': nan,
#  '11023': nan,
#  '1745': nan,
#  '10370': nan,
#  '3950': nan,
#  '9753': nan,
#  '10658': nan,
#  '8442': nan,
#  '8183': nan,
#  '165': 'philosophy',
#  '2235': nan,
#  '7986': nan,
#  '10100': nan,
#  '11999': nan,
#  '7774': nan,
#  '2762': nan,
#  '12248': nan,
#  '11024': nan,
#  '2973': nan,
#  '3633': 'social science',
#  '4586': 'engineering',
#  '4930': 'math',
#  '7938': nan,
#  '7450': nan,
#  '2169': nan,
#  '3369': nan,
#  '1690': nan,
#  '3536': nan,
#  '3446': nan,
#  '11282': 'art',
#  '10366': nan,
#  '9485': nan,
#  '5017': 'physics',
#  '6516': nan,
#  '11445': 'economics',
#  '2681': nan,
#  '201': nan,
#  '7342': nan,
#  '4274': nan,
#  '9756': nan,
#  '10040': nan,
#  '5321': nan,
#  '545': 'computer',
#  '7676': nan,
#  '7322': nan,
#  '9722': nan,
#  '8416': nan,
#  '2997': nan,
#  '6949': nan,
#  '10728': nan,
#  '4931': 'math',
#  '11680': 'foreign language',
#  '11832': nan,
#  '9228': nan,
#  '9982': nan,
#  '10185': nan,
#  '3056': nan,
#  '3452': nan,
#  '10187': nan,
#  '4606': 'history',
#  '12104': nan,
#  '9408': nan,
#  '12149': nan,
#  '2863': nan,
#  '9964': nan,
#  '2244': 'social science',
#  '6940': nan,
#  '10984': nan,
#  '7901': nan,
#  '11985': nan,
#  '9623': nan,
#  '4445': 'art',
#  '5151': nan,
#  '4178': nan,
#  '645': 'math',
#  '9770': nan,
#  '4448': 'computer',
#  '7483': nan,
#  '12096': nan,
#  '11272': nan,
#  '8004': nan,
#  '5891': nan,
#  '10218': nan,
#  '1383': nan,
#  '6732': nan,
#  '7050': nan,
#  '6672': nan,
#  '3172': nan,
#  '11190': nan,
#  '3616': 'engineering',
#  '2833': nan,
#  '9718': nan,
#  '1810': nan,
#  '5604': nan,
#  '4339': nan,
#  '2114': nan,
#  '3922': nan,
#  '8213': nan,
#  '9331': 'education',
#  '7346': nan,
#  '4968': 'physics',
#  '8178': nan,
#  '503': 'philosophy',
#  '3428': nan,
#  '12094': nan,
#  '1744': nan,
#  '6676': nan,
#  '12231': nan,
#  '1688': nan,
#  '10836': nan,
#  '5528': nan,
#  '193': 'computer',
#  '7281': nan,
#  '7060': nan,
#  '8879': nan,
#  '9866': nan,
#  '9860': 'economics',
#  '10632': nan,
#  '10801': nan,
#  '4145': 'economics',
#  '6727': nan,
#  '11978': nan,
#  '9303': nan,
#  '3439': nan,
#  '8278': nan,
#  '4661': nan,
#  '4001': nan,
#  '4656': nan,
#  '529': 'art',
#  '10618': nan,
#  '12046': nan,
#  '10577': nan,
#  '10208': nan,
#  '4000': nan,
#  '6721': nan,
#  '11444': nan,
#  '11617': nan,
#  '10167': nan,
#  '6807': nan,
#  '11987': 'foreign language',
#  '5200': nan,
#  '723': 'business',
#  '10951': nan,
#  '9660': 'physics',
#  '7122': nan,
#  '8072': nan,
#  '1862': nan,
#  '9980': nan,
#  '8055': nan,
#  '10203': nan,
#  '10942': nan,
#  '4918': 'education',
#  '2765': 'history',
#  '10559': nan,
#  '6892': nan,
#  '8726': nan,
#  '10120': nan,
#  '10512': nan,
#  '4359': 'computer',
#  '3847': nan,
#  '570': 'engineering',
#  '7719': nan,
#  '8145': 'biology',
#  '10422': nan,
#  '5587': nan,
#  '9146': nan,
#  '4488': 'engineering',
#  '484': nan,
#  '6298': nan,
#  '4518': 'computer',
#  '4660': nan,
#  '574': 'business',
#  '4320': nan,
#  '9921': nan,
#  '9198': nan,
#  '3160': nan,
#  '8503': nan,
#  '10510': nan,
#  '10724': nan,
#  '3629': nan,
#  '1861': nan,
#  '6917': nan,
#  '9706': nan,
#  '4552': 'education',
#  '4177': nan,
#  '464': nan,
#  '7707': nan,
#  '10767': nan,
#  '9368': nan,
#  '3376': nan,
#  '3767': nan,
#  '7414': nan,
#  '7660': nan,
#  '7765': nan,
#  '8654': 'economics',
#  '3169': nan,
#  '3790': nan,
#  '6679': nan,
#  '9030': nan,
#  '3921': nan,
#  '10011': nan,
#  '6885': nan,
#  '5085': nan,
#  '7175': nan,
#  '663': nan,
#  '2995': nan,
#  '9655': nan,
#  '4811': nan,
#  '11309': nan,
#  '8288': nan,
#  '7182': 'engineering',
#  '11319': nan,
#  '11123': nan,
#  '5386': 'physics',
#  '6484': nan,
#  '9001': nan,
#  '5729': nan,
#  '11521': nan,
#  '7093': nan,
#  '12228': nan,
#  '7340': nan,
#  '7244': 'environment',
#  '1942': 'art',
#  '3479': nan,
#  '6145': nan,
#  '2003': nan,
#  '8122': nan,
#  '238': nan,
#  '10436': nan,
#  '10007': nan,
#  '5187': 'engineering',
#  '3411': nan,
#  '5018': nan,
#  '8969': nan,
#  '10353': nan,
#  '5304': nan,
#  '602': nan,
#  '11636': nan,
#  '3126': 'physics',
#  '8635': 'foreign language',
#  '8203': nan,
#  '793': 'math',
#  '9673': nan,
#  '8267': nan,
#  '10768': nan,
#  '7976': nan,
#  '546': 'engineering',
#  '9325': nan,
#  '3069': 'physics',
#  '10360': nan,
#  '7882': nan,
#  '10435': nan,
#  '6624': nan,
#  '11526': 'literature',
#  '8407': nan,
#  '9924': nan,
#  '9466': nan,
#  '10318': nan,
#  '7327': nan,
#  '8445': nan,
#  '8211': nan,
#  '7849': nan,
#  '766': nan,
#  '11992': nan,
#  '2819': nan,
#  '6704': nan,
#  '1801': 'economics',
#  '8361': nan,
#  '11016': nan,
#  '7855': nan,
#  '7374': nan,
#  '660': 'computer',
#  '8561': nan,
#  '7609': nan,
#  '1589': 'engineering',
#  '10825': nan,
#  '6901': nan,
#  '7358': nan,
#  '73': 'literature',
#  '8129': nan,
#  '6999': nan,
#  '6988': nan,
#  '11071': nan,
#  '4555': 'physics',
#  '3391': nan,
#  '11154': nan,
#  '10723': nan,
#  '4011': nan,
#  ...}

# %%
# add course_category feature
all_features['course_category'] = [category_convert(category_dict.get(str(x), None)) for x in all_features['course_id']]

# %%
all_features.head()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 772                   2              2                 0                 0
# 773                  21             21                 6                 4
# 774                  74             74                 9                14
# 776                  19             19                 0                 3
# 777                   4              4                 0                 0
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 772                        0                 0                 0
# 773                        3                 0                 1
# 774                       10                 1                 8
# 776                        3                 1                 2
# 777                        0                 0                 0
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 772                        0                    0                   0  ...
# 773                        0                    0                   0  ...
# 774                        0                    0                   0  ...
# 776                        0                    0                   0  ...
# 777                        0                    0                   0  ...
#
#            close_courseware_count  truth  username  \
# enroll_id
# 772                             0      1      5981
# 773                             1      1   1544995
# 774                             9      1   1072798
# 776                             2      0    561867
# 777                             1      1   1368125
#
#                                        course_id  age  gender  education  \
# enroll_id
# 772        course-v1:TsinghuaX+70800232X+2015_T2   29       0          3
# 773        course-v1:TsinghuaX+70800232X+2015_T2    0       0          0
# 774        course-v1:TsinghuaX+70800232X+2015_T2    0       0          0
# 776        course-v1:TsinghuaX+70800232X+2015_T2   37       0          6
# 777        course-v1:TsinghuaX+70800232X+2015_T2    0       0          0
#
#            user_enroll_count  course_enroll_count  course_category
# enroll_id
# 772                        6                 1333                0
# 773                        2                 1333                0
# 774                        5                 1333                0
# 776                        6                 1333                0
# 777                       11                 1333                0
#
# [5 rows x 32 columns]

# %%
numeric_features = [c for c in train_features.columns if 'count' in c or 'time' in c or 'num' in c]

# %%
numeric_features
# Out:
# ['action_count',
#  'session_count',
#  'seek_video_count',
#  'play_video_count',
#  'pause_video_count',
#  'stop_video_count',
#  'load_video_count',
#  'problem_get_count',
#  'problem_check_count',
#  'problem_save_count',
#  'reset_problem_count',
#  'problem_check_correct_count',
#  'problem_check_incorrect_count',
#  'create_thread_count',
#  'create_comment_count',
#  'delete_thread_count',
#  'delete_comment_count',
#  'click_info_count',
#  'click_courseware_count',
#  'click_about_count',
#  'click_forum_count',
#  'click_progress_count',
#  'close_courseware_count']

# %%
# dump actual features as a pickle file
pkl.dump(numeric_features, open(os.path.join(data_path, 'act_features.pkl'),'wb'))

# %%
all_feature_names = numeric_features + ['age','course_enroll_num','user_enroll_num']

# %%
# perform Standard Scalar Transformation: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
scaler = StandardScaler()
transformed_df = scaler.fit_transform(all_features[numeric_features])

# %%
transformed_df.shape
# Out:
# (225642, 23)

# %%
for i, n_f in enumerate(numeric_features):
    print(i, n_f)
    all_features[n_f] = transformed_df[:,i]
# Out:
# 0 action_count
# 1 session_count
# 2 seek_video_count
# 3 play_video_count
# 4 pause_video_count
# 5 stop_video_count
# 6 load_video_count
# 7 problem_get_count
# 8 problem_check_count
# 9 problem_save_count
# 10 reset_problem_count
# 11 problem_check_correct_count
# 12 problem_check_incorrect_count
# 13 create_thread_count
# 14 create_comment_count
# 15 delete_thread_count
# 16 delete_comment_count
# 17 click_info_count
# 18 click_courseware_count
# 19 click_about_count
# 20 click_forum_count
# 21 click_progress_count
# 22 close_courseware_count

# %%
all_features.head()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 772           -0.228387      -0.228387         -0.243043         -0.296739
# 773           -0.204883      -0.204883         -0.115253         -0.242027
# 774           -0.139320      -0.139320         -0.051358         -0.105248
# 776           -0.207357      -0.207357         -0.243043         -0.255705
# 777           -0.225912      -0.225912         -0.243043         -0.296739
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 772                -0.333535         -0.059298         -0.480968
# 773                -0.296012         -0.059298         -0.445267
# 774                -0.208460         -0.057709         -0.195358
# 776                -0.296012         -0.057709         -0.409566
# 777                -0.333535         -0.059298         -0.480968
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 772                -0.042412            -0.305844           -0.202161  ...
# 773                -0.042412            -0.305844           -0.202161  ...
# 774                -0.042412            -0.305844           -0.202161  ...
# 776                -0.042412            -0.305844           -0.202161  ...
# 777                -0.042412            -0.305844           -0.202161  ...
#
#            close_courseware_count  truth  username  \
# enroll_id
# 772                     -0.464309      1      5981
# 773                     -0.428065      1   1544995
# 774                     -0.138111      1   1072798
# 776                     -0.391821      0    561867
# 777                     -0.428065      1   1368125
#
#                                        course_id  age  gender  education  \
# enroll_id
# 772        course-v1:TsinghuaX+70800232X+2015_T2   29       0          3
# 773        course-v1:TsinghuaX+70800232X+2015_T2    0       0          0
# 774        course-v1:TsinghuaX+70800232X+2015_T2    0       0          0
# 776        course-v1:TsinghuaX+70800232X+2015_T2   37       0          6
# 777        course-v1:TsinghuaX+70800232X+2015_T2    0       0          0
#
#            user_enroll_count  course_enroll_count  course_category
# enroll_id
# 772                        6                 1333                0
# 773                        2                 1333                0
# 774                        5                 1333                0
# 776                        6                 1333                0
# 777                       11                 1333                0
#
# [5 rows x 32 columns]

# %%
all_features.tail()
# Out:
#            action_count  session_count  seek_video_count  play_video_count  \
# enroll_id
# 424714         0.108086       0.108086          1.141348          0.469226
# 424720        -0.218490      -0.218490         -0.200446         -0.283061
# 424243         0.228078       0.228078         -0.157850          0.674395
# 424555         0.555891       0.555891          3.803637          0.578649
# 424585        -0.044069      -0.044069          0.076432          0.031532
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 424714              0.441931         -0.051356          0.018849
# 424720             -0.308520         -0.059298         -0.480968
# 424243              0.779634         -0.035474          0.554367
# 424555              0.879694         -0.025945          1.089886
# 424585              0.141751         -0.048180          0.018849
#
#            problem_get_count  problem_check_count  problem_save_count  ...  \
# enroll_id                                                              ...
# 424714             -0.042412            -0.305844           -0.202161  ...
# 424720             -0.042412            -0.305844           -0.202161  ...
# 424243             -0.033690             0.033785           -0.202161  ...
# 424555             -0.013340             0.430019            0.554097  ...
# 424585             -0.039505            -0.192634           -0.013096  ...
#
#            close_courseware_count  truth  username  \
# enroll_id
# 424714                   0.151842      1   6776637
# 424720                  -0.464309      1   6776128
# 424243                   0.840483      1   6776321
# 424555                   1.420390      1   6775492
# 424585                  -0.391821      0   6776600
#
#                                        course_id  age  gender  education  \
# enroll_id
# 424714     course-v1:TsinghuaX+00670122X+2017_T1    0       0          0
# 424720     course-v1:TsinghuaX+00670122X+2017_T1    0       0          0
# 424243     course-v1:TsinghuaX+00670122X+2017_T1    0       0          0
# 424555     course-v1:TsinghuaX+00670122X+2017_T1    0       0          0
# 424585     course-v1:TsinghuaX+00670122X+2017_T1    0       0          0
#
#            user_enroll_count  course_enroll_count  course_category
# enroll_id
# 424714                     2                  426                0
# 424720                     1                  426                0
# 424243                     1                  426                0
# 424555                     1                  426                0
# 424585                     1                  426                0
#
# [5 rows x 32 columns]

# %%
#extract user cluster
#cluster_label = np.load('cluster/label_5_10time.npy', allow_pickle=True)
#user_cluster_id = pkl.load(open('cluster/user_dict','r'))

#all_feat['cluster_label'] = [cluster_label[user_cluster_id[u]] for u in all_feat['username']]

# save training and testing as CSV files
all_features.loc[train_features.index].to_csv(os.path.join(data_path, 'train_normalized_features.csv'))
all_features.loc[test_features.index].to_csv(os.path.join(data_path, 'test_normalized_features.csv'))

# %%
# let's clean drop some features just to see...
all_features.drop(columns=['session_count', 'username', 'course_id', 'user_enroll_count', 'course_enroll_count'])
# Out:
#            action_count  seek_video_count  play_video_count  \
# enroll_id
# 772           -0.228387         -0.243043         -0.296739
# 773           -0.204883         -0.115253         -0.242027
# 774           -0.139320         -0.051358         -0.105248
# 776           -0.207357         -0.243043         -0.255705
# 777           -0.225912         -0.243043         -0.296739
# ...                 ...               ...               ...
# 424714         0.108086          1.141348          0.469226
# 424720        -0.218490         -0.200446         -0.283061
# 424243         0.228078         -0.157850          0.674395
# 424555         0.555891          3.803637          0.578649
# 424585        -0.044069          0.076432          0.031532
#
#            pause_video_count  stop_video_count  load_video_count  \
# enroll_id
# 772                -0.333535         -0.059298         -0.480968
# 773                -0.296012         -0.059298         -0.445267
# 774                -0.208460         -0.057709         -0.195358
# 776                -0.296012         -0.057709         -0.409566
# 777                -0.333535         -0.059298         -0.480968
# ...                      ...               ...               ...
# 424714              0.441931         -0.051356          0.018849
# 424720             -0.308520         -0.059298         -0.480968
# 424243              0.779634         -0.035474          0.554367
# 424555              0.879694         -0.025945          1.089886
# 424585              0.141751         -0.048180          0.018849
#
#            problem_get_count  problem_check_count  problem_save_count  \
# enroll_id
# 772                -0.042412            -0.305844           -0.202161
# 773                -0.042412            -0.305844           -0.202161
# 774                -0.042412            -0.305844           -0.202161
# 776                -0.042412            -0.305844           -0.202161
# 777                -0.042412            -0.305844           -0.202161
# ...                      ...                  ...                 ...
# 424714             -0.042412            -0.305844           -0.202161
# 424720             -0.042412            -0.305844           -0.202161
# 424243             -0.033690             0.033785           -0.202161
# 424555             -0.013340             0.430019            0.554097
# 424585             -0.039505            -0.192634           -0.013096
#
#            reset_problem_count  ...  click_courseware_count  \
# enroll_id                       ...
# 772                  -0.103969  ...               -0.428333
# 773                  -0.103969  ...               -0.394335
# 774                  -0.103969  ...               -0.139346
# 776                  -0.103969  ...               -0.360336
# 777                  -0.103969  ...               -0.411334
# ...                        ...  ...                     ...
# 424714               -0.103969  ...                0.234639
# 424720               -0.103969  ...               -0.411334
# 424243               -0.103969  ...                0.948608
# 424555               -0.103969  ...                1.509585
# 424585               -0.103969  ...                0.047646
#
#            click_about_count  click_forum_count  click_progress_count  \
# enroll_id
# 772                -0.293695          -0.177350             -0.284796
# 773                -0.159877          -0.177350             -0.284796
# 774                -0.427513          -0.177350             -0.284796
# 776                -0.159877          -0.177350             -0.284796
# 777                -0.293695          -0.177350             -0.284796
# ...                      ...                ...                   ...
# 424714              0.643029          -0.177350             -0.284796
# 424720             -0.026059          -0.177350             -0.284796
# 424243              1.847389          -0.177350             -0.284796
# 424555              0.107758           0.120029              0.624071
# 424585              0.643029          -0.177350             -0.284796
#
#            close_courseware_count  truth  age  gender  education  \
# enroll_id
# 772                     -0.464309      1   29       0          3
# 773                     -0.428065      1    0       0          0
# 774                     -0.138111      1    0       0          0
# 776                     -0.391821      0   37       0          6
# 777                     -0.428065      1    0       0          0
# ...                           ...    ...  ...     ...        ...
# 424714                   0.151842      1    0       0          0
# 424720                  -0.464309      1    0       0          0
# 424243                   0.840483      1    0       0          0
# 424555                   1.420390      1    0       0          0
# 424585                  -0.391821      0    0       0          0
#
#            course_category
# enroll_id
# 772                      0
# 773                      0
# 774                      0
# 776                      0
# 777                      0
# ...                    ...
# 424714                   0
# 424720                   0
# 424243                   0
# 424555                   0
# 424585                   0
#
# [225642 rows x 27 columns]

# %%
all_features.loc[train_features.index].to_csv(os.path.join(data_path, 'train_normalized_trimmed_features.csv'))
all_features.loc[test_features.index].to_csv(os.path.join(data_path, 'test_normalized_trimmed_features.csv'))
